# %%
import pandas as pd

# %% [markdown]
# ##### comandos importantes de read_csv " names(nombre de las cabeceras, headers(validar si tiene cabecera  o no
# ##### skiprows(obviar determinada cantidad de filas", sep(separador )

# %%
RUTA = ('C:\\Users\\WIN10\\Desktop\\DS_TOTAL\\VACUNACION.csv')
DATASET = pd.read_csv(RUTA)

# %%
DATASET.describe()
# Out:
#        total_vaccinations  people_vaccinated  people_fully_vaccinated  \
# count        4.360700e+04       4.129400e+04             3.880200e+04
# mean         4.592964e+07       1.770508e+07             1.413830e+07
# std          2.246004e+08       7.078731e+07             5.713920e+07
# min          0.000000e+00       0.000000e+00             1.000000e+00
# 25%          5.264100e+05       3.494642e+05             2.439622e+05
# 50%          3.590096e+06       2.187310e+06             1.722140e+06
# 75%          1.701230e+07       9.152520e+06             7.559870e+06
# max          3.263129e+09       1.275541e+09             1.240777e+09
#
#        daily_vaccinations_raw  daily_vaccinations  \
# count            3.536200e+04        8.621300e+04
# mean             2.705996e+05        1.313055e+05
# std              1.212427e+06        7.682388e+05
# min              0.000000e+00        0.000000e+00
# 25%              4.668000e+03        9.000000e+02
# ...

# %%
DATASET.head(2)
# Out:
#        country iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG  2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG  2021-02-23                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN              1367.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                             0.0                            0.0
# 1                             NaN                            NaN
#
#    people_fully_vaccinated_per_hundred  daily_vaccinations_per_million  \
# 0                                  NaN                             NaN
# 1                                  NaN                            34.0
#
#                                             vaccines  \
# ...

# %%
DATASET.tail(2)
# Out:
#         country iso_code        date  total_vaccinations  people_vaccinated  \
# 86510  Zimbabwe      ZWE  2022-03-28           8934360.0          4975433.0
# 86511  Zimbabwe      ZWE  2022-03-29           9039729.0          5053114.0
#
#        people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 86510                3501493.0                 89321.0            100614.0
# 86511                3510256.0                105369.0            103751.0
#
#        total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 86510                            59.2                          32.97
# 86511                            59.9                          33.48
#
#        people_fully_vaccinated_per_hundred  daily_vaccinations_per_million  \
# 86510                                23.20                          6667.0
# 86511                                23.26                          6874.0
#
# ...

# %%
DATASET.shape
# Out:
# (86512, 15)

# %%
CABECERA = ["CABECERA_1","CABECERA_2","CABECERA_3","CABECERA_4","CABECERA_5","CABECERA_6",
            "CABECERA_7","CABECERA_8","CABECERA_9","CABECERA_10",
            "CABECERA_11","CABECERA_12","CABECERA_13","CABECERA_14","CABECERA_15"]

# %%
DATASET.rename(
   columns =  { 'x1':'R1','x2':'e2', 'x4':'z1', 'x5:'o2'
    }

)

# %%
CABECERA
# Out:
# ['CABECERA_1',
#  'CABECERA_2',
#  'CABECERA_3',
#  'CABECERA_4',
#  'CABECERA_5',
#  'CABECERA_6',
#  'CABECERA_7',
#  'CABECERA_8',
#  'CABECERA_9',
#  'CABECERA_10',
#  'CABECERA_11',
#  'CABECERA_12',
#  'CABECERA_13',
#  'CABECERA_14',
#  'CABECERA_15']

# %%
RUTA = ('C:\\Users\\WIN10\\Desktop\\DS_TOTAL\\VACUNACION.csv')
DATASET = pd.read_csv(RUTA, header = None, names = CABECERA)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (3,4,5,6,7,8,9,10,11) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
DATASET
# Out:
#         CABECERA_1 CABECERA_2  CABECERA_3          CABECERA_4  \
# 0          country   iso_code        date  total_vaccinations
# 1      Afghanistan        AFG  2021-02-22                 0.0
# 2      Afghanistan        AFG  2021-02-23                 NaN
# 3      Afghanistan        AFG  2021-02-24                 NaN
# 4      Afghanistan        AFG  2021-02-25                 NaN
# ...            ...        ...         ...                 ...
# 86508     Zimbabwe        ZWE  2022-03-25           8691642.0
# 86509     Zimbabwe        ZWE  2022-03-26           8791728.0
# 86510     Zimbabwe        ZWE  2022-03-27           8845039.0
# 86511     Zimbabwe        ZWE  2022-03-28           8934360.0
# 86512     Zimbabwe        ZWE  2022-03-29           9039729.0
#
#               CABECERA_5               CABECERA_6              CABECERA_7  \
# 0      people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw
# ...

# %%
RUTA = ('C:\\Users\\WIN10\\Desktop\\DS_TOTAL\\VACUNACION.csv')
DATASET = pd.read_csv(RUTA, header = None, names = CABECERA, skiprows = 1, sep = ',')

# %%
DATASET
# Out:
#         CABECERA_1 CABECERA_2  CABECERA_3  CABECERA_4  CABECERA_5  CABECERA_6  \
# 0      Afghanistan        AFG  2021-02-22         0.0         0.0         NaN
# 1      Afghanistan        AFG  2021-02-23         NaN         NaN         NaN
# 2      Afghanistan        AFG  2021-02-24         NaN         NaN         NaN
# 3      Afghanistan        AFG  2021-02-25         NaN         NaN         NaN
# 4      Afghanistan        AFG  2021-02-26         NaN         NaN         NaN
# ...            ...        ...         ...         ...         ...         ...
# 86507     Zimbabwe        ZWE  2022-03-25   8691642.0   4814582.0   3473523.0
# 86508     Zimbabwe        ZWE  2022-03-26   8791728.0   4886242.0   3487962.0
# 86509     Zimbabwe        ZWE  2022-03-27   8845039.0   4918147.0   3493763.0
# 86510     Zimbabwe        ZWE  2022-03-28   8934360.0   4975433.0   3501493.0
# 86511     Zimbabwe        ZWE  2022-03-29   9039729.0   5053114.0   3510256.0
#
# ...

# %% [markdown]
# #### carga de datos desde excel

# %%
ARCHIVO = 'C:\\Users\\WIN10\\Desktop\POWET BI 3 EN 1\\ARCHIVOS\\Inmuebles.xlsx'

# %%
DATA_EX = pd.read_excel(ARCHIVO, 'reporte_ventas')

# %%
DATA_EX.head(5)
# Out:
#    Referencia  FechaAlta              Tip      Oper  \
# 0           1 2016-01-18  Estacionamiento  Alquiler
# 1           2 2016-01-20          Oficina  Alquiler
# 2           3 2016-01-20            Local     Venta
# 3           4 2016-01-24       Industrial     Venta
# 4           5 2016-02-03     Departamento     Venta
#
#                          Location  Sup M2 Precio_venta     Fventa Vendedor  \
# 0     América Norte|México|Cancún     215     $1154980 2017-01-14  Joaquín
# 1    América Norte|México|Tijuana     287     $2851058 2017-01-02  Joaquín
# 2  América Norte|México|Monterrey      40      $321680 2017-01-11    Jesús
# 3     América Norte|México|Cancún     178     $1142938 2017-01-23  Joaquín
# 4  América Norte|México|Monterrey     275     $2141700 2017-01-08    Jesús
#
#   Estatus\nV = Vendida\nP = Proceso  Columna 1  Columna 2  Columna 3
# 0                                 V        NaN        NaN        NaN
# ...

# %% [markdown]
# ##### CARGA DE TXT

# %%
RUTA_2 = 'C:\\Users\\WIN10\\Desktop\\DS_TOTAL\\matches-2003-2022.txt'
FOOTBAL = pd.read_csv(RUTA_2, sep = ';', encoding = 'latin-1')

# %%
FOOTBAL.head(20)
# Out:
#     #ROUND        DATE   HOUR         HOME-TEAM SCORE         AWAY-TEAM
# 0        1  29/03/2003  18:00        Guarani/SP   4x2          Vasco/RJ
# 1        1  29/03/2003  18:00       Atlético/PR   2x0         Grêmio/RS
# 2        1  30/03/2003  18:00          Goiás/GO   2x2       Paysandu/PA
# 3        1  30/03/2003  18:00    Corinthians/SP   0x3       Atlético/MG
# 4        1  30/03/2003  16:00       Flamengo/RJ   1x1       Coritiba/PR
# 5        1  30/03/2003  16:00       Criciúma/SC   2x0     Fluminense/RJ
# 6        1  30/03/2003  16:00      Juventude/RS   2x2      São Paulo/SP
# 7        1  30/03/2003  16:00      Fortaleza/CE   0x0          Bahia/BA
# 8        1  30/03/2003  16:00        Vitória/BA   1x1    Figueirense/SC
# 9        1  30/03/2003  16:00       Cruzeiro/MG   2x2    São Caetano/SP
# 10       1  30/03/2003  16:00  Internacional/RS   1x1    Ponte Preta/SP
# 11       1  30/03/2003  16:00         Santos/SP   2x2         Paraná/PR
# ...

# %%
FOOTBAL.tail(20)
# Out:
#       #ROUND        DATE   HOUR         HOME-TEAM SCORE         AWAY-TEAM
# 8006       2  09/11/2022  23:30      Fortaleza/CE   6x0     Bragantino/SP
# 8007       2  09/11/2022  22:00           Avaí/SC   2x0          Ceará/CE
# 8008       2  09/11/2022  22:00       Coritiba/PR   2x2    Corinthians/SP
# 8009       2  09/11/2022  22:00     Fluminense/RJ   3x0          Goiás/GO
# 8010       2  09/11/2022  00:30      São Paulo/SP   0x1  Internacional/RS
# 8011       2  10/11/2022  23:00       Atlético/MG   3x0         Cuiabá/PR
# 8012       2  10/11/2022  23:00       Botafogo/RJ   3x0         Santos/SP
# 8013       2  10/11/2022  00:30       Atlético/GO   1x1       Atlético/PR
# 8014       2  10/11/2022  00:30      Juventude/RS   2x2       Flamengo/RJ
# 8015       2  10/11/2022  00:30      Palmeiras/SP   2x1        América/MG
# 8016       2  12/11/2022  19:00       Flamengo/RJ   1x2           Avaí/SC
# 8017       2  13/11/2022  19:00        América/MG   1x1       Atlético/GO
# ...

# %%
FOOTBAL.describe()
# Out:
#             #ROUND
# count  8026.000000
# mean      1.504485
# std       0.500011
# min       1.000000
# 25%       1.000000
# 50%       2.000000
# 75%       2.000000
# max       2.000000

# %% [markdown]
# #### CARGA DE FORMATO .JSON

# %%
DATA_I = 'C:\\Users\\WIN10\\Desktop\\DS_TOTAL\IRIS\\IRIS.json'
IRIS = pd.read_json(DATA_I)

# %%
IRIS
# Out:
#      sepalLength  sepalWidth  petalLength  petalWidth    species
# 0            5.1         3.5          1.4         0.2     setosa
# 1            4.9         3.0          1.4         0.2     setosa
# 2            4.7         3.2          1.3         0.2     setosa
# 3            4.6         3.1          1.5         0.2     setosa
# 4            5.0         3.6          1.4         0.2     setosa
# ..           ...         ...          ...         ...        ...
# 145          6.7         3.0          5.2         2.3  virginica
# 146          6.3         2.5          5.0         1.9  virginica
# 147          6.5         3.0          5.2         2.0  virginica
# 148          6.2         3.4          5.4         2.3  virginica
# 149          5.9         3.0          5.1         1.8  virginica
#
# [150 rows x 5 columns]

# %%
IRIS.head(10)
# Out:
#    sepalLength  sepalWidth  petalLength  petalWidth species
# 0          5.1         3.5          1.4         0.2  setosa
# 1          4.9         3.0          1.4         0.2  setosa
# 2          4.7         3.2          1.3         0.2  setosa
# 3          4.6         3.1          1.5         0.2  setosa
# 4          5.0         3.6          1.4         0.2  setosa
# 5          5.4         3.9          1.7         0.4  setosa
# 6          4.6         3.4          1.4         0.3  setosa
# 7          5.0         3.4          1.5         0.2  setosa
# 8          4.4         2.9          1.4         0.2  setosa
# 9          4.9         3.1          1.5         0.1  setosa

# %%
IRIS.tail(10)
# Out:
#      sepalLength  sepalWidth  petalLength  petalWidth    species
# 140          6.7         3.1          5.6         2.4  virginica
# 141          6.9         3.1          5.1         2.3  virginica
# 142          5.8         2.7          5.1         1.9  virginica
# 143          6.8         3.2          5.9         2.3  virginica
# 144          6.7         3.3          5.7         2.5  virginica
# 145          6.7         3.0          5.2         2.3  virginica
# 146          6.3         2.5          5.0         1.9  virginica
# 147          6.5         3.0          5.2         2.0  virginica
# 148          6.2         3.4          5.4         2.3  virginica
# 149          5.9         3.0          5.1         1.8  virginica

# %%
IRIS.describe()
# Out:
#        sepalLength  sepalWidth  petalLength  petalWidth
# count   150.000000  150.000000   150.000000  150.000000
# mean      5.843333    3.057333     3.758000    1.199333
# std       0.828066    0.435866     1.765298    0.762238
# min       4.300000    2.000000     1.000000    0.100000
# 25%       5.100000    2.800000     1.600000    0.300000
# 50%       5.800000    3.000000     4.350000    1.300000
# 75%       6.400000    3.300000     5.100000    1.800000
# max       7.900000    4.400000     6.900000    2.500000

# %%
IRIS[['sepalLength', 'sepalWidth', 'petalWidth']][0:2]
# Out:
#    sepalLength  sepalWidth  petalWidth
# 0          5.1         3.5         0.2
# 1          4.9         3.0         0.2

# %%
IRIS['sepalLength'] [0] = 6.2
# Out:
# C:\Users\WIN10\AppData\Local\Temp/ipykernel_10072/3245012379.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   IRIS['sepalLength'] [0] = 6.2

# %%
IRIS['sepalLength'] [0]
# Out:
# 6.2

# %%
IRIS
# Out:
#      sepalLength  sepalWidth  petalLength  petalWidth    species
# 0            6.2         3.5          1.4         0.2     setosa
# 1            4.9         3.0          1.4         0.2     setosa
# 2            4.7         3.2          1.3         0.2     setosa
# 3            4.6         3.1          1.5         0.2     setosa
# 4            5.0         3.6          1.4         0.2     setosa
# ..           ...         ...          ...         ...        ...
# 145          6.7         3.0          5.2         2.3  virginica
# 146          6.3         2.5          5.0         1.9  virginica
# 147          6.5         3.0          5.2         2.0  virginica
# 148          6.2         3.4          5.4         2.3  virginica
# 149          5.9         3.0          5.1         1.8  virginica
#
# [150 rows x 5 columns]

# %%
IRIS.loc[:, ['sepalLength','sepalWidth','petalLength','petalWidth']]
# Out:
#      sepalLength  sepalWidth  petalLength  petalWidth
# 0            6.2         3.5          1.4         0.2
# 1            4.9         3.0          1.4         0.2
# 2            4.7         3.2          1.3         0.2
# 3            4.6         3.1          1.5         0.2
# 4            5.0         3.6          1.4         0.2
# ..           ...         ...          ...         ...
# 145          6.7         3.0          5.2         2.3
# 146          6.3         2.5          5.0         1.9
# 147          6.5         3.0          5.2         2.0
# 148          6.2         3.4          5.4         2.3
# 149          5.9         3.0          5.1         1.8
#
# [150 rows x 4 columns]

# %%
IRIS_1 = IRIS.loc[:, ['sepalLength','sepalWidth','petalLength','petalWidth']]

# %%
IRIS_1
# Out:
#      sepalLength  sepalWidth  petalLength  petalWidth
# 0            6.2         3.5          1.4         0.2
# 1            4.9         3.0          1.4         0.2
# 2            4.7         3.2          1.3         0.2
# 3            4.6         3.1          1.5         0.2
# 4            5.0         3.6          1.4         0.2
# ..           ...         ...          ...         ...
# 145          6.7         3.0          5.2         2.3
# 146          6.3         2.5          5.0         1.9
# 147          6.5         3.0          5.2         2.0
# 148          6.2         3.4          5.4         2.3
# 149          5.9         3.0          5.1         1.8
#
# [150 rows x 4 columns]

# %%
IRIS_1.to_json('C:\\Users\\WIN10\\Desktop\\DS_TOTAL.json')

# %%
IRIS_PRUEBA = 'C:\\Users\WIN10\Desktop\\DS_TOTAL.json'
PRUEBA = pd.read_json(IRIS_PRUEBA)

# %%
PRUEBA
# Out:
#      sepalLength  sepalWidth  petalLength  petalWidth
# 0            6.2         3.5          1.4         0.2
# 1            4.9         3.0          1.4         0.2
# 2            4.7         3.2          1.3         0.2
# 3            4.6         3.1          1.5         0.2
# 4            5.0         3.6          1.4         0.2
# ..           ...         ...          ...         ...
# 145          6.7         3.0          5.2         2.3
# 146          6.3         2.5          5.0         1.9
# 147          6.5         3.0          5.2         2.0
# 148          6.2         3.4          5.4         2.3
# 149          5.9         3.0          5.1         1.8
#
# [150 rows x 4 columns]

# %% [markdown]
# #### EXPORTAR DATOS CSV, XLSX, .JSON, TXT

# %%
IRIS_1.to_csv('C:\\Users\\WIN10\\Desktop\\DS_TOTAL.csv')
IRIS_1.to_excel('C:\\Users\\WIN10\\Desktop\\DS_TOTAL.xls')
IRIS_1.to_excel('C:\\Users\\WIN10\\Desktop\\DS_TOTAL.xlsx')
IRIS_1.to_csv('C:\\Users\\WIN10\\Desktop\\DS_TOTAL.txt')
IRIS_1.to_json('C:\\Users\\WIN10\\Desktop\\DS_TOTAL.json')
