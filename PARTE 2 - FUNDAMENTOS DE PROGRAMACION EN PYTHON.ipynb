# %% [markdown]
# ## PARTE 2.3 TIPO DE DATOS LÓGICO / BOOLEANO
# #### True

# %%
2 == 5
3 < 5
1 == 1

True + 1

5 + True

(1==1)*3
# Out:
# 3

# %% [markdown]
# ### FALSE

# %%
False + 1
# Out:
# 1

# %% [markdown]
# ### 2.4 OPERADORES RELACIONALES

# %%
# DIFERENTE QUE 

print(6!=8)
print(6!=6)
# Out:
# True
# False

# %% [markdown]
# #### COMPARACION CON VARIABLES

# %%
VAR = 10
VAR ==10
# Out:
# True

# %%
C1 = "HOLA"
C2 = "Hola"
C3 = "hola"

print(C1 == C2)
     print (C1 == C3)
# Out:
#   File "C:\Users\WIN10\AppData\Local\Temp/ipykernel_8656/1588256772.py", line 6
#     print (C1 == C3)
#     ^
# IndentationError: unexpected indent

# %% [markdown]
# ### OPERADORES RESUMIDOS

# %%
(1<5) and (5<8)

(1<5<8)
# Out:
# True

# %%
print(1<5<8)
# Out:
# True

# %% [markdown]
# ### OPERADORES LOGICOS

# %%
##IMPORTAR IMAGENES 
from IPython.display import Image
Image(filename = "C:\\Users\\WIN10\\Documents\\CERTIFICACION PYTHON\\RECURSOS\\TABLAS DE VERDAD\\TABLAS DE VERDAD1.PNG"
)

# %%
from IPython.display import Image
Image(filename = "C:\\Users\\WIN10\\Documents\\CERTIFICACION PYTHON\\RECURSOS\\TABLAS DE VERDAD\\tabla de verdad.PNG")

# %%
print(not True) 
print(not False)
# Out:
# False
# True

# %%
#CONJUNCION - AND

print((True) and (True))

print((False) and (True))

print((1<5) and (4>7))
print((1==1) and (True))
# Out:
# True
# False
# False
# True

# %% [markdown]
# ## EXPRESIONES ANIDADAS

# %%
(((1==1) and (1>=3)) * 3 + 1) > 8/2
#(((True) and (False)) * 3 + 1) > 8/2
#((False) * 3 + 1) > 8 / 2
#(0 + 1) > 8 / 2
#(1) > 4
# False
# Out:
# False

# %% [markdown]
# ## OPERACIONES DE ASIGNACION

# %%
#ASIGNACION SIMPLE
VARIABLE = 10
VARIABLE = VARIABLE + 5
print(VARIABLE + 1)
# Out:
# 16

# %%
#SUMA EN ASIGNACION

VARIABLE = 10
VARIABLE += 5
print(VARIABLE)
# Out:
# 15

# %%
#SUMA DE ASIGNACION 

VARIABLE = 10
VARIABLE -= 5
print(VARIABLE)
# Out:
# 5

# %%
VARIABLE = 10 
VARIABLE *= 5
print(VARIABLE)
# Out:
# 50

# %%
#DIVISION DE ASIGNACION 
VARIABLE = 10
VARIABLE /= 5
print(VARIABLE)
# Out:
# 2.0

# %%
#MÓDULO DE ASIGNACION
VARIABLE = 10
VARIABLE %= 5
print(VARIABLE)
# Out:
# 0

# %%
#POTENCIA EN ASIGNACION 
VARIABLE = 10
VARIABLE **= 5
print(VARIABLE)
# Out:
# 100000

# %% [markdown]
# ## ALEATORIOS CON MÓDULO RANDOM ( GENERAR NUMEROS ALEATORIOS )

# %%
import random

# %%
#GENERAR UN ALEATORIO DECIMAL ENTRE 0 - 1
random.random()
# Out:
# 0.27714260458599627

# %%
#GENERAR UN ALEATORIO DECIMAL UNIFORME ENTRE 2 NUMEROS
random.uniform(20,30)
# Out:
# 29.405605439597807

# %%
#GENERAR UN ALEATORIO ENTERO ENTRE 2 NUMEROS
random.randrange(20,90,5)
# Out:
# 35

# %%
## CADENA DE CARACTER ALEATORIO
CADENA = "PYTHON-2021"
random.choice(CADENA)
# Out:
# '2'

# %% [markdown]
# ## PARTE 2.9    ALEATORIOS CON NUMPY

# %%
import numpy

# %%
#GENERAR UN ALEATORIO DECIMAL ENTRE 0 - 1
numpy.random.random()
# Out:
# 0.7201819193084806

# %%
#GENERAR UN ALEATORIO ENTERO ENTRE 2 NUMEROS
numpy.random.randint(20,30)
numpy.random.randint(20)
numpy.random.randint(20,30,4)
# Out:
# array([20, 20, 21, 22])

# %%
#DEFINICION DE LA SEMILLA EN LA GENERACION DE NUMEROS ALEATORIOS 
numpy.random.seed(1234)
numpy.random.random()
# Out:
# 0.1915194503788923
