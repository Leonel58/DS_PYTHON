# %%
import pandas as pd

# %%
RUTA = "C:\\Users\\WIN10\\Desktop\\DS_TOTAL\\COV\\COVID19.csv"

# %%
COVID = pd.read_csv(RUTA, sep = ",")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
COVID
# Out:
#         FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM  SEXO  \
# 0                2022-08-09      z53cb3       2      12           9     2
# 1                2022-08-09      zze974       1       6          24     1
# 2                2022-08-09      zz7202       1      12          16     2
# 3                2022-08-09      z405fd       1      12           9     2
# 4                2022-08-09      z26b82       2      12           9     1
# ...                     ...         ...     ...     ...         ...   ...
# 8830340          2022-08-09     m0f93ef       2      12          15     1
# 8830341          2022-08-09     m08e5a6       2      12          15     1
# 8830342          2022-08-09     m0bea6e       2      12          15     1
# 8830343          2022-08-09     m00eab3       2      12          15     2
# 8830344          2022-08-09     m0bfb28       2      12          15     1
#
#          ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE  ...  \
# ...

# %%
COVID.loc[1000:10000][["FECHA_ACTUALIZACION","ID_REGISTRO","ORIGEN","SECTOR","ENTIDAD_UM","SEXO",
                      "ENTIDAD_NAC","ENTIDAD_RES","MUNICIPIO_RES","TIPO_PACIENTE","OTRO_CASO",
                      "TOMA_MUESTRA_LAB","RESULTADO_LAB","TOMA_MUESTRA_ANTIGENO","RESULTADO_ANTIGENO",
                      "CLASIFICACION_FINAL","MIGRANTE","PAIS_NACIONALIDAD","PAIS_ORIGEN","UCI"]]
# Out:
#       FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM  SEXO  \
# 1000           2022-08-09     gz5b652       2      12           9     1
# 1001           2022-08-09     gzz5c5e       2      12           9     1
# 1002           2022-08-09     gzz5d5f       2      12           9     2
# 1003           2022-08-09     gz2caff       2       4          26     2
# 1004           2022-08-09     gz56366       2      12           9     1
# ...                   ...         ...     ...     ...         ...   ...
# 9996           2022-08-09     g024125       2      12           9     1
# 9997           2022-08-09     g002baa       1      12           9     2
# 9998           2022-08-09     g008bd3       1      12           9     1
# 9999           2022-08-09     g1b19ab       1      12           9     1
# 10000          2022-08-09     g0e499a       1      12           9     2
#
#        ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE  OTRO_CASO  \
# ...

# %%
DATOS_CORRECTOS = COVID.loc[1000:10000][["FECHA_ACTUALIZACION","ID_REGISTRO","ORIGEN","SECTOR","ENTIDAD_UM","SEXO",
                      "ENTIDAD_NAC","ENTIDAD_RES","MUNICIPIO_RES","TIPO_PACIENTE","OTRO_CASO",
                      "TOMA_MUESTRA_LAB","RESULTADO_LAB","TOMA_MUESTRA_ANTIGENO","RESULTADO_ANTIGENO",
                      "CLASIFICACION_FINAL","MIGRANTE","PAIS_NACIONALIDAD","PAIS_ORIGEN","UCI"]]

# %%
DATOS_CORRECTOS
# Out:
#       FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM  SEXO  \
# 1000           2022-08-09     gz5b652       2      12           9     1
# 1001           2022-08-09     gzz5c5e       2      12           9     1
# 1002           2022-08-09     gzz5d5f       2      12           9     2
# 1003           2022-08-09     gz2caff       2       4          26     2
# 1004           2022-08-09     gz56366       2      12           9     1
# ...                   ...         ...     ...     ...         ...   ...
# 9996           2022-08-09     g024125       2      12           9     1
# 9997           2022-08-09     g002baa       1      12           9     2
# 9998           2022-08-09     g008bd3       1      12           9     1
# 9999           2022-08-09     g1b19ab       1      12           9     1
# 10000          2022-08-09     g0e499a       1      12           9     2
#
#        ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE  OTRO_CASO  \
# ...

# %%
COVID.shape
# Out:
# (8830345, 40)

# %%
COVID.iloc[20000:25000,5:15]
# Out:
#        SEXO  ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE  \
# 20000     1            9            9              8              1
# 20001     1            9            9              2              1
# 20002     2            9            9             10              1
# 20003     1            9            9              2              1
# 20004     2            9            9             10              1
# ...     ...          ...          ...            ...            ...
# 24995     1            9            9             17              1
# 24996     2            9            9              5              1
# 24997     2            9            9              5              1
# 24998     2            9            9              5              1
# 24999     1            9            9              5              1
#
#       FECHA_INGRESO FECHA_SINTOMAS   FECHA_DEF  INTUBADO  NEUMONIA
# 20000    2021-11-09     2021-11-09  9999-99-99        97         2
# ...

# %%
COVID_SECUN = COVID.iloc[20000:25000,5:15]

# %%
COVID_SECUN
# Out:
#        SEXO  ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE  \
# 20000     1            9            9              8              1
# 20001     1            9            9              2              1
# 20002     2            9            9             10              1
# 20003     1            9            9              2              1
# 20004     2            9            9             10              1
# ...     ...          ...          ...            ...            ...
# 24995     1            9            9             17              1
# 24996     2            9            9              5              1
# 24997     2            9            9              5              1
# 24998     2            9            9              5              1
# 24999     1            9            9              5              1
#
#       FECHA_INGRESO FECHA_SINTOMAS   FECHA_DEF  INTUBADO  NEUMONIA
# 20000    2021-11-09     2021-11-09  9999-99-99        97         2
# ...

# %%
COVID_COPY_1 = COVID_SECUN.copy()

# %%
COVID_COPY_2 = DATOS_CORRECTOS.copy()

# %%
COVID_COPY_1 = COVID_SECUN.copy()
pd.isnull(COVID_COPY_1)
# Out:
#         SEXO  ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE  \
# 20000  False        False        False          False          False
# 20001  False        False        False          False          False
# 20002  False        False        False          False          False
# 20003  False        False        False          False          False
# 20004  False        False        False          False          False
# ...      ...          ...          ...            ...            ...
# 24995  False        False        False          False          False
# 24996  False        False        False          False          False
# 24997  False        False        False          False          False
# 24998  False        False        False          False          False
# 24999  False        False        False          False          False
#
#        FECHA_INGRESO  FECHA_SINTOMAS  FECHA_DEF  INTUBADO  NEUMONIA
# 20000          False           False      False     False     False
# ...

# %%
COVID_COPY_1 = COVID_SECUN.copy()
pd.isnull(COVID_COPY_1[["SEXO"]])
# Out:
#         SEXO
# 20000  False
# 20001  False
# 20002  False
# 20003  False
# 20004  False
# ...      ...
# 24995  False
# 24996  False
# 24997  False
# 24998  False
# 24999  False
#
# [5000 rows x 1 columns]

# %%
COVID_COPY_1 = COVID_SECUN.copy()
pd.notnull(COVID_COPY_1)
# Out:
#        SEXO  ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE  \
# 20000  True         True         True           True           True
# 20001  True         True         True           True           True
# 20002  True         True         True           True           True
# 20003  True         True         True           True           True
# 20004  True         True         True           True           True
# ...     ...          ...          ...            ...            ...
# 24995  True         True         True           True           True
# 24996  True         True         True           True           True
# 24997  True         True         True           True           True
# 24998  True         True         True           True           True
# 24999  True         True         True           True           True
#
#        FECHA_INGRESO  FECHA_SINTOMAS  FECHA_DEF  INTUBADO  NEUMONIA
# 20000           True            True       True      True      True
# ...

# %%
COVID_COPY_1 = COVID_SECUN.copy()
pd.isnull(COVID_COPY_1).values.sum()
# Out:
# 0

# %%
COVID_COPY_1 = COVID_SECUN.copy()
pd.notnull(COVID_COPY_1).values.sum()
# Out:
# 50000

# %%
COVID_COPY_1 = COVID_SECUN.copy()
COVID_COPY_1["ENTIDAD_NAC"] = COVID_COPY_1["ENTIDAD_NAC"].fillna("-")
COVID_COPY_1
# Out:
#        SEXO  ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE  \
# 20000     1            9            9              8              1
# 20001     1            9            9              2              1
# 20002     2            9            9             10              1
# 20003     1            9            9              2              1
# 20004     2            9            9             10              1
# ...     ...          ...          ...            ...            ...
# 24995     1            9            9             17              1
# 24996     2            9            9              5              1
# 24997     2            9            9              5              1
# 24998     2            9            9              5              1
# 24999     1            9            9              5              1
#
#       FECHA_INGRESO FECHA_SINTOMAS   FECHA_DEF  INTUBADO  NEUMONIA
# 20000    2021-11-09     2021-11-09  9999-99-99        97         2
# ...

# %%
COVID_COPY_1 = COVID_SECUN.copy()
COVID_COPY_1 = COVID_COPY_1.fillna("90")
COVID_COPY_1
# Out:
#        SEXO  ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE  \
# 20000     1            9            9              8              1
# 20001     1            9            9              2              1
# 20002     2            9            9             10              1
# 20003     1            9            9              2              1
# 20004     2            9            9             10              1
# ...     ...          ...          ...            ...            ...
# 24995     1            9            9             17              1
# 24996     2            9            9              5              1
# 24997     2            9            9              5              1
# 24998     2            9            9              5              1
# 24999     1            9            9              5              1
#
#       FECHA_INGRESO FECHA_SINTOMAS   FECHA_DEF  INTUBADO  NEUMONIA
# 20000    2021-11-09     2021-11-09  9999-99-99        97         2
# ...

# %%
COVID_COPY_1.columns
# Out:
# Index(['SEXO', 'ENTIDAD_NAC', 'ENTIDAD_RES', 'MUNICIPIO_RES', 'TIPO_PACIENTE',
#        'FECHA_INGRESO', 'FECHA_SINTOMAS', 'FECHA_DEF', 'INTUBADO', 'NEUMONIA'],
#       dtype='object')

# %%
COVID_COPY_1 = COVID_SECUN.copy()
COVID_COPY_1["MUNICIPIO_RES"] = COVID_COPY_1["MUNICIPIO_RES"].fillna(COVID_COPY_1["MUNICIPIO_RES"].mean()) 
COVID_COPY_1
# Out:
#        SEXO  ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE  \
# 20000     1            9            9              8              1
# 20001     1            9            9              2              1
# 20002     2            9            9             10              1
# 20003     1            9            9              2              1
# 20004     2            9            9             10              1
# ...     ...          ...          ...            ...            ...
# 24995     1            9            9             17              1
# 24996     2            9            9              5              1
# 24997     2            9            9              5              1
# 24998     2            9            9              5              1
# 24999     1            9            9              5              1
#
#       FECHA_INGRESO FECHA_SINTOMAS   FECHA_DEF  INTUBADO  NEUMONIA
# 20000    2021-11-09     2021-11-09  9999-99-99        97         2
# ...

# %%
COVID_COPY_1
# Out:
#        SEXO  ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE  \
# 20000     1            9            9              8              1
# 20001     1            9            9              2              1
# 20002     2            9            9             10              1
# 20003     1            9            9              2              1
# 20004     2            9            9             10              1
# ...     ...          ...          ...            ...            ...
# 24995     1            9            9             17              1
# 24996     2            9            9              5              1
# 24997     2            9            9              5              1
# 24998     2            9            9              5              1
# 24999     1            9            9              5              1
#
#       FECHA_INGRESO FECHA_SINTOMAS   FECHA_DEF  INTUBADO  NEUMONIA
# 20000    2021-11-09     2021-11-09  9999-99-99        97         2
# ...

# %%
import pandas as pd

# %%
RUTA = "C:\\Users\\WIN10\\Desktop\\DS_TOTAL\\COV\\COVID19.csv"

# %%
CVID_19 = pd.read_csv(RUTA, sep = ",")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
CVID_19
# Out:
#         FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM  SEXO  \
# 0                2022-08-09      z53cb3       2      12           9     2
# 1                2022-08-09      zze974       1       6          24     1
# 2                2022-08-09      zz7202       1      12          16     2
# 3                2022-08-09      z405fd       1      12           9     2
# 4                2022-08-09      z26b82       2      12           9     1
# ...                     ...         ...     ...     ...         ...   ...
# 8830340          2022-08-09     m0f93ef       2      12          15     1
# 8830341          2022-08-09     m08e5a6       2      12          15     1
# 8830342          2022-08-09     m0bea6e       2      12          15     1
# 8830343          2022-08-09     m00eab3       2      12          15     2
# 8830344          2022-08-09     m0bfb28       2      12          15     1
#
#          ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE  ...  \
# ...

# %%
CVID_19.iloc[:10000,:25]
# Out:
#      FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM  SEXO  \
# 0             2022-08-09      z53cb3       2      12           9     2
# 1             2022-08-09      zze974       1       6          24     1
# 2             2022-08-09      zz7202       1      12          16     2
# 3             2022-08-09      z405fd       1      12           9     2
# 4             2022-08-09      z26b82       2      12           9     1
# ...                  ...         ...     ...     ...         ...   ...
# 9995          2022-08-09     g15479f       1      12           9     2
# 9996          2022-08-09     g024125       2      12           9     1
# 9997          2022-08-09     g002baa       1      12           9     2
# 9998          2022-08-09     g008bd3       1      12           9     1
# 9999          2022-08-09     g1b19ab       1      12           9     1
#
#       ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE  ... EDAD  \
# ...

# %%
 CVID_25 = CVID_19.iloc[:10000,:25]

# %%
CVID_25
# Out:
#      FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM  SEXO  \
# 0             2022-08-09      z53cb3       2      12           9     2
# 1             2022-08-09      zze974       1       6          24     1
# 2             2022-08-09      zz7202       1      12          16     2
# 3             2022-08-09      z405fd       1      12           9     2
# 4             2022-08-09      z26b82       2      12           9     1
# ...                  ...         ...     ...     ...         ...   ...
# 9995          2022-08-09     g15479f       1      12           9     2
# 9996          2022-08-09     g024125       2      12           9     1
# 9997          2022-08-09     g002baa       1      12           9     2
# 9998          2022-08-09     g008bd3       1      12           9     1
# 9999          2022-08-09     g1b19ab       1      12           9     1
#
#       ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE  ... EDAD  \
# ...

# %%
CVID_19.iloc[300000:400000,26:39]
# Out:
#         CARDIOVASCULAR  OBESIDAD  RENAL_CRONICA  TABAQUISMO  OTRO_CASO  \
# 300000               2         2              2           2          2
# 300001               2         2              2           2          2
# 300002               2         2              2           1          2
# 300003               2         1              2           2          1
# 300004               2         2              2           2          2
# ...                ...       ...            ...         ...        ...
# 399995               2         2              2           2          1
# 399996               2         2              2           2          1
# 399997               2         2              2           1          1
# 399998               2         2              2           2          2
# 399999               2         2              2           2          1
#
#         TOMA_MUESTRA_LAB  RESULTADO_LAB  TOMA_MUESTRA_ANTIGENO  \
# ...

# %%
CVID_26 = CVID_19.iloc[300000:400000,26:39]

# %%
CVID_25
# Out:
#      FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM  SEXO  \
# 0             2022-08-09      z53cb3       2      12           9     2
# 1             2022-08-09      zze974       1       6          24     1
# 2             2022-08-09      zz7202       1      12          16     2
# 3             2022-08-09      z405fd       1      12           9     2
# 4             2022-08-09      z26b82       2      12           9     1
# ...                  ...         ...     ...     ...         ...   ...
# 9995          2022-08-09     g15479f       1      12           9     2
# 9996          2022-08-09     g024125       2      12           9     1
# 9997          2022-08-09     g002baa       1      12           9     2
# 9998          2022-08-09     g008bd3       1      12           9     1
# 9999          2022-08-09     g1b19ab       1      12           9     1
#
#       ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE  ... EDAD  \
# ...

# %%
CVID_26
# Out:
#         CARDIOVASCULAR  OBESIDAD  RENAL_CRONICA  TABAQUISMO  OTRO_CASO  \
# 300000               2         2              2           2          2
# 300001               2         2              2           2          2
# 300002               2         2              2           1          2
# 300003               2         1              2           2          1
# 300004               2         2              2           2          2
# ...                ...       ...            ...         ...        ...
# 399995               2         2              2           2          1
# 399996               2         2              2           2          1
# 399997               2         2              2           1          1
# 399998               2         2              2           2          2
# 399999               2         2              2           2          1
#
#         TOMA_MUESTRA_LAB  RESULTADO_LAB  TOMA_MUESTRA_ANTIGENO  \
# ...

# %%
CVID_26[["PAIS_NACIONALIDAD","PAIS_ORIGEN"]]
# Out:
#        PAIS_NACIONALIDAD PAIS_ORIGEN
# 300000            México          97
# 300001            México          97
# 300002            México          97
# 300003            México          97
# 300004            México          97
# ...                  ...         ...
# 399995            México          97
# 399996            México          97
# 399997            México          97
# 399998            México          97
# 399999            México          97
#
# [100000 rows x 2 columns]

# %%
NACIONALIDAD_ORIGEN= CVID_26[["PAIS_NACIONALIDAD","PAIS_ORIGEN"]]

# %%
NACIONALIDAD_ORIGEN
# Out:
#        PAIS_NACIONALIDAD PAIS_ORIGEN
# 300000            México          97
# 300001            México          97
# 300002            México          97
# 300003            México          97
# 300004            México          97
# ...                  ...         ...
# 399995            México          97
# 399996            México          97
# 399997            México          97
# 399998            México          97
# 399999            México          97
#
# [100000 rows x 2 columns]

# %%
import pandas as pd

# %%
RUTA = "C:\\Users\\WIN10\\Desktop\\DS_TOTAL\\COV\\COVID19.csv"

# %%
CD_19 = pd.read_csv(RUTA, sep = ",")
CD_19.head(5)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#   FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM  SEXO  \
# 0          2022-08-09      z53cb3       2      12           9     2
# 1          2022-08-09      zze974       1       6          24     1
# 2          2022-08-09      zz7202       1      12          16     2
# 3          2022-08-09      z405fd       1      12           9     2
# 4          2022-08-09      z26b82       2      12           9     1
#
#    ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE  ... OTRO_CASO  \
# 0            9            9              2              1  ...         1
# 1           24           24             35              1  ...         1
# 2           16           16            112              1  ...         1
# ...

# %%
COVID_19 = CD_19.copy()
COVID_19
# Out:
#         FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM  SEXO  \
# 0                2022-08-09      z53cb3       2      12           9     2
# 1                2022-08-09      zze974       1       6          24     1
# 2                2022-08-09      zz7202       1      12          16     2
# 3                2022-08-09      z405fd       1      12           9     2
# 4                2022-08-09      z26b82       2      12           9     1
# ...                     ...         ...     ...     ...         ...   ...
# 8830340          2022-08-09     m0f93ef       2      12          15     1
# 8830341          2022-08-09     m08e5a6       2      12          15     1
# 8830342          2022-08-09     m0bea6e       2      12          15     1
# 8830343          2022-08-09     m00eab3       2      12          15     2
# 8830344          2022-08-09     m0bfb28       2      12          15     1
#
#          ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE  ...  \
# ...

# %%
COVID_19 = CD_19.copy()
COVID_19.iloc[1000:5000,15:25]
COVID_19

# %%
CD_19.ilo[1000:5000,[15:25]

# %%
import pandas as pd

# %%
RUTA = "C:\\Users\\WIN10\\Desktop\\DS_TOTAL\\COV\\COVID19.csv"

# %%
COV = pd.read_csv(RUTA)
COV.head(10)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#   FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM  SEXO  \
# 0          2022-08-09      z53cb3       2      12           9     2
# 1          2022-08-09      zze974       1       6          24     1
# 2          2022-08-09      zz7202       1      12          16     2
# 3          2022-08-09      z405fd       1      12           9     2
# 4          2022-08-09      z26b82       2      12           9     1
# 5          2022-08-09      z23d9d       1      12          22     2
# 6          2022-08-09      1009d6       1      12          30     1
# 7          2022-08-09      z5c8ce       1      12          14     1
# 8          2022-08-09      0c5c89       1      12          27     1
# ...

# %%
import pandas as pd

# %%
COVID = COV.copy()

# %%
COVID = COV.copy()
COVID = COV.iloc[5000:100000,:15].copy()
COVID
# Out:
#       FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM  SEXO  \
# 5000           2022-08-09     g1537f3       2      12           9     2
# 5001           2022-08-09     g133290       1      12           9     2
# 5002           2022-08-09     g12bc04       2      12           9     1
# 5003           2022-08-09     g1d02f3       2      12           9     2
# 5004           2022-08-09     g09b813       2      12           9     1
# ...                   ...         ...     ...     ...         ...   ...
# 99995          2022-08-09      34b2a9       2      12           9     1
# 99996          2022-08-09      28e999       2      12           9     1
# 99997          2022-08-09      260c73       2      12           9     1
# 99998          2022-08-09      3287b4       2       7          14     2
# 99999          2022-08-09      2f7b5d       2       6           9     1
#
#        ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE FECHA_INGRESO  \
# ...

# %%
COVID.shape
# Out:
# (95000, 15)

# %%
COVID
# Out:
#       FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM  SEXO  \
# 5000           2022-08-09     g1537f3       2      12           9     2
# 5001           2022-08-09     g133290       1      12           9     2
# 5002           2022-08-09     g12bc04       2      12           9     1
# 5003           2022-08-09     g1d02f3       2      12           9     2
# 5004           2022-08-09     g09b813       2      12           9     1
# ...                   ...         ...     ...     ...         ...   ...
# 99995          2022-08-09      34b2a9       2      12           9     1
# 99996          2022-08-09      28e999       2      12           9     1
# 99997          2022-08-09      260c73       2      12           9     1
# 99998          2022-08-09      3287b4       2       7          14     2
# 99999          2022-08-09      2f7b5d       2       6           9     1
#
#        ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE FECHA_INGRESO  \
# ...

# %%
COVID_COL = COVID.append({
    "FECHA_ACTUALIZACION":"2023-08-09",
    "ID_REGISTRO":"H333290",
    "ORIGEN":10,
    "SECTOR":15,
    "ENTIDAD_UM":12,
    "SEXO":2,
    "ENTIDAD_NAC":15,
    "MUNICIPIO_RES":12,
    "TIPO_PACIENTE":1,
    "FECHA_INGRESO":"9999-99-19",
    "INTUBADO":2,
    "NEUMONIA":3
    
}, ignore_index=True)

# %%
COVID_COL
# Out:
#       FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM  SEXO  \
# 0              2022-08-09     g1537f3       2      12           9     2
# 1              2022-08-09     g133290       1      12           9     2
# 2              2022-08-09     g12bc04       2      12           9     1
# 3              2022-08-09     g1d02f3       2      12           9     2
# 4              2022-08-09     g09b813       2      12           9     1
# ...                   ...         ...     ...     ...         ...   ...
# 94996          2022-08-09      28e999       2      12           9     1
# 94997          2022-08-09      260c73       2      12           9     1
# 94998          2022-08-09      3287b4       2       7          14     2
# 94999          2022-08-09      2f7b5d       2       6           9     1
# 95000          2023-08-09     H333290      10      15          12     2
#
#        ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE FECHA_INGRESO  \
# ...

# %%
COVID_COL = COVID_COL.append({
    "FECHA_ACTUALIZACION" : "2024-08-07",
    "ID_REGISTRO": "g1332110",
    "ORIGEN":3,
    "SECTOR":50,
    "ENTIDAD_UM":10,
    "SEXO":5,
    "ENTIDAD_NAC":54,
    "ENTIDAD_RES":14,
    "MUNICIPIO_RES":30,
    "TIPO_PACIENTE":5,
    "FECHA_INGRESO":"2021-01-04",
    "FECHA_SINTOMAS":"2021-08-23",
    "FECHA_DEF":"9999-99-99",
    "INTUBADO":100,
    "NEUMONIA":8
    
},ignore_index=True)

COVID_COL
# Out:
#       FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM  SEXO  \
# 0              2022-08-09     g1537f3       2      12           9     2
# 1              2022-08-09     g133290       1      12           9     2
# 2              2022-08-09     g12bc04       2      12           9     1
# 3              2022-08-09     g1d02f3       2      12           9     2
# 4              2022-08-09     g09b813       2      12           9     1
# ...                   ...         ...     ...     ...         ...   ...
# 95000          2023-08-09     H333290      10      15          12     2
# 95001                 NaN    g1332110       3      50          10     5
# 95002                 NaN    g1332110       3      50          10     5
# 95003          2024-08-07    g1332110       3      50          10     5
# 95004          2024-08-07    g1332110       3      50          10     5
#
#        ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE FECHA_INGRESO  \
# ...

# %%
DATA1 = COVID_COL.iloc[:50,:5].copy()
DATA1
# Out:
#    FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM
# 0           2022-08-09     g1537f3       2      12           9
# 1           2022-08-09     g133290       1      12           9
# 2           2022-08-09     g12bc04       2      12           9
# 3           2022-08-09     g1d02f3       2      12           9
# 4           2022-08-09     g09b813       2      12           9
# 5           2022-08-09     g033403       2      12           9
# 6           2022-08-09     g0ca0a9       1      12           9
# 7           2022-08-09     g0a576c       1      12           9
# 8           2022-08-09     g1d06e2       2      12           9
# 9           2022-08-09     g0046fc       2      12           9
# 10          2022-08-09     g03434e       2       9           9
# 11          2022-08-09     g0423a8       2      12           9
# 12          2022-08-09     g0c4550       1      12           9
# 13          2022-08-09     g14f68e       2      12           9
# ...

# %%
DATA2 = COVID_COL.iloc[:50,6:13].copy()
DATA2
# Out:
#     ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE FECHA_INGRESO  \
# 0             9          9.0              8              1    2021-08-23
# 1             9         15.0             33              1    2021-03-02
# 2             9          9.0             15              1    2021-08-09
# 3             9          9.0             14              1    2021-02-03
# 4             9          9.0             13              1    2021-09-30
# 5             9          9.0             15              1    2021-09-07
# 6             9         15.0             33              1    2021-03-02
# 7            31         31.0             50              1    2021-08-17
# 8             9          9.0             14              1    2021-03-03
# 9             9          9.0             12              1    2021-02-17
# 10            9         15.0             13              1    2021-12-22
# 11            9          9.0              8              1    2021-02-20
# ...

# %%
DATA1.columns
# Out:
# Index(['FECHA_ACTUALIZACION', 'ID_REGISTRO', 'ORIGEN', 'SECTOR', 'ENTIDAD_UM'], dtype='object')

# %%
DATA_GENERADO = pd.DataFrame ({
    "COL1":DATA1["FECHA_ACTUALIZACION"],
    "COL2":DATA1["ORIGEN"],
    "COL3":DATA2["ENTIDAD_RES"],
    "COL4":DATA2["FECHA_INGRESO"],
    "COL5":DATA2["FECHA_DEF"],
    "COL6":DATA2["TIPO_PACIENTE"],
    "COL7":DATA1["ENTIDAD_UM"]
    
}).copy()

DATA_GENERADO
# Out:
#           COL1  COL2  COL3        COL4        COL5  COL6  COL7
# 0   2022-08-09     2   9.0  2021-08-23  9999-99-99     1     9
# 1   2022-08-09     1  15.0  2021-03-02  9999-99-99     1     9
# 2   2022-08-09     2   9.0  2021-08-09  9999-99-99     1     9
# 3   2022-08-09     2   9.0  2021-02-03  9999-99-99     1     9
# 4   2022-08-09     2   9.0  2021-09-30  9999-99-99     1     9
# 5   2022-08-09     2   9.0  2021-09-07  9999-99-99     1     9
# 6   2022-08-09     1  15.0  2021-03-02  9999-99-99     1     9
# 7   2022-08-09     1  31.0  2021-08-17  9999-99-99     1     9
# 8   2022-08-09     2   9.0  2021-03-03  9999-99-99     1     9
# 9   2022-08-09     2   9.0  2021-02-17  9999-99-99     1     9
# 10  2022-08-09     2  15.0  2021-12-22  9999-99-99     1     9
# 11  2022-08-09     2   9.0  2021-02-20  9999-99-99     1     9
# 12  2022-08-09     1   9.0  2021-03-02  9999-99-99     1     9
# 13  2022-08-09     2   9.0  2021-02-21  9999-99-99     1     9
# ...

# %%
DATA2.columns
# Out:
# Index(['ENTIDAD_NAC', 'ENTIDAD_RES', 'MUNICIPIO_RES', 'TIPO_PACIENTE',
#        'FECHA_INGRESO', 'FECHA_SINTOMAS', 'FECHA_DEF'],
#       dtype='object')

# %%
DATA_GENERADO2 = pd.DataFrame({
    "SR":DATA1["SECTOR"],
    "RO":DATA1["ID_REGISTRO"],
    "FA":DATA1["FECHA_ACTUALIZACION"],
    "EN":DATA2["ENTIDAD_NAC"],
    "MR":DATA2["MUNICIPIO_RES"],
    "FI":DATA2["FECHA_INGRESO"],
    "FD":DATA2["FECHA_DEF"]
    
}).copy()

DATA_GENERADO2
# Out:
#     SR       RO          FA  EN  MR          FI          FD
# 0   12  g1537f3  2022-08-09   9   8  2021-08-23  9999-99-99
# 1   12  g133290  2022-08-09   9  33  2021-03-02  9999-99-99
# 2   12  g12bc04  2022-08-09   9  15  2021-08-09  9999-99-99
# 3   12  g1d02f3  2022-08-09   9  14  2021-02-03  9999-99-99
# 4   12  g09b813  2022-08-09   9  13  2021-09-30  9999-99-99
# 5   12  g033403  2022-08-09   9  15  2021-09-07  9999-99-99
# 6   12  g0ca0a9  2022-08-09   9  33  2021-03-02  9999-99-99
# 7   12  g0a576c  2022-08-09  31  50  2021-08-17  9999-99-99
# 8   12  g1d06e2  2022-08-09   9  14  2021-03-03  9999-99-99
# 9   12  g0046fc  2022-08-09   9  12  2021-02-17  9999-99-99
# 10   9  g03434e  2022-08-09   9  13  2021-12-22  9999-99-99
# 11  12  g0423a8  2022-08-09   9   8  2021-02-20  9999-99-99
# 12  12  g0c4550  2022-08-09   9   5  2021-03-02  9999-99-99
# 13  12  g14f68e  2022-08-09   9   8  2021-02-21  9999-99-99
# 14  12  g0c3e12  2022-08-09   9   5  2021-03-04  9999-99-99
# ...

# %%
DATA1.columns
# Out:
# Index(['FECHA_ACTUALIZACION', 'ID_REGISTRO', 'ORIGEN', 'SECTOR', 'ENTIDAD_UM'], dtype='object')

# %%
COVID
# Out:
#         FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM  SEXO  \
# 0                2022-08-09      z53cb3       2      12           9     2
# 1                2022-08-09      zze974       1       6          24     1
# 2                2022-08-09      zz7202       1      12          16     2
# 3                2022-08-09      z405fd       1      12           9     2
# 4                2022-08-09      z26b82       2      12           9     1
# ...                     ...         ...     ...     ...         ...   ...
# 8830340          2022-08-09     m0f93ef       2      12          15     1
# 8830341          2022-08-09     m08e5a6       2      12          15     1
# 8830342          2022-08-09     m0bea6e       2      12          15     1
# 8830343          2022-08-09     m00eab3       2      12          15     2
# 8830344          2022-08-09     m0bfb28       2      12          15     1
#
#          ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE  ...  \
# ...

# %%
COL1 = COVID.iloc[100:500,25:40].copy()
COL1
# Out:
#      OTRA_COM  CARDIOVASCULAR  OBESIDAD  RENAL_CRONICA  TABAQUISMO  OTRO_CASO  \
# 100         2               2         2              2           2          2
# 101         2               2         2              2           2          2
# 102         2               2         2              2           2          2
# 103         2               2         2              2           2          2
# 104         2               2         2              2           2          2
# ..        ...             ...       ...            ...         ...        ...
# 495         2               2         2              2           2          2
# 496         2               2         2              2           2          2
# 497         2               2         2              2           2          2
# 498         2               2         2              2           2          2
# 499         2               2         2              1           2          1
#
# ...

# %%
COL2 = COVID.iloc[100:500,:20].copy()
COL2
# Out:
#     FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM  SEXO  \
# 100          2022-08-09     gz4bfe0       2      12           9     1
# 101          2022-08-09     gz1279d       2       4          26     1
# 102          2022-08-09     gz4c4e8       2      12           9     1
# 103          2022-08-09     gz454b6       1      12           9     1
# 104          2022-08-09     gz2af4d       2       4          15     2
# ..                  ...         ...     ...     ...         ...   ...
# 495          2022-08-09     gz1da12       2       9           9     1
# 496          2022-08-09     gz35a3a       1       4           3     1
# 497          2022-08-09     gzzc3bf       2       9           9     2
# 498          2022-08-09     gz194a9       2       9           9     1
# 499          2022-08-09     gzz7729       1       4           3     2
#
#      ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE FECHA_INGRESO  \
# ...

# %%
COL2.head(2)
# Out:
#     FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM  SEXO  \
# 100          2022-08-09     gz4bfe0       2      12           9     1
# 101          2022-08-09     gz1279d       2       4          26     1
#
#      ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE FECHA_INGRESO  \
# 100            9            9              3              1    2021-01-11
# 101           26           26             55              1    2021-12-24
#
#     FECHA_SINTOMAS   FECHA_DEF  INTUBADO  NEUMONIA  EDAD  NACIONALIDAD  \
# 100     2021-01-07  9999-99-99        97         2     8             1
# 101     2021-12-21  9999-99-99        97         2    32             1
#
#      EMBARAZO  HABLA_LENGUA_INDIG  INDIGENA
# 100         2                   2         2
# 101         2                   2         2

# %%
DATA_UNION = pd.DataFrame({
    "P_N":COL1["PAIS_NACIONALIDAD"],
    "R_A":COL1["RESULTADO_ANTIGENO"],
    "O_B":COL1["OBESIDAD"],
    
    "F_A":COL2["FECHA_ACTUALIZACION"],
    "I_R":COL2["ID_REGISTRO"],
    "F_I":COL2["FECHA_INGRESO"],
    "E_D":COL2["EDAD"]
    
    
})

DATA_UNION
# Out:
#         P_N  R_A  O_B         F_A      I_R         F_I  E_D
# 100  México    2    2  2022-08-09  gz4bfe0  2021-01-11    8
# 101  México    1    2  2022-08-09  gz1279d  2021-12-24   32
# 102  México    2    2  2022-08-09  gz4c4e8  2021-04-05   27
# 103  México    2    2  2022-08-09  gz454b6  2021-09-01   48
# 104  México    2    2  2022-08-09  gz2af4d  2022-01-03   41
# ..      ...  ...  ...         ...      ...         ...  ...
# 495  México    2    2  2022-08-09  gz1da12  2021-12-22   49
# 496  México    1    2  2022-08-09  gz35a3a  2021-12-29   18
# 497  México    2    2  2022-08-09  gzzc3bf  2021-12-24   52
# 498  México    2    2  2022-08-09  gz194a9  2021-12-22   64
# 499  México    1    2  2022-08-09  gzz7729  2021-12-29   29
#
# [400 rows x 7 columns]

# %%
COVID
# Out:
#         FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM  SEXO  \
# 0                2022-08-09      z53cb3       2      12           9     2
# 1                2022-08-09      zze974       1       6          24     1
# 2                2022-08-09      zz7202       1      12          16     2
# 3                2022-08-09      z405fd       1      12           9     2
# 4                2022-08-09      z26b82       2      12           9     1
# ...                     ...         ...     ...     ...         ...   ...
# 8830340          2022-08-09     m0f93ef       2      12          15     1
# 8830341          2022-08-09     m08e5a6       2      12          15     1
# 8830342          2022-08-09     m0bea6e       2      12          15     1
# 8830343          2022-08-09     m00eab3       2      12          15     2
# 8830344          2022-08-09     m0bfb28       2      12          15     1
#
#          ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE  ...  \
# ...

# %%
COVID.columns
# Out:
# Index(['FECHA_ACTUALIZACION', 'ID_REGISTRO', 'ORIGEN', 'SECTOR', 'ENTIDAD_UM',
#        'SEXO', 'ENTIDAD_NAC', 'ENTIDAD_RES', 'MUNICIPIO_RES', 'TIPO_PACIENTE',
#        'FECHA_INGRESO', 'FECHA_SINTOMAS', 'FECHA_DEF', 'INTUBADO', 'NEUMONIA',
#        'EDAD', 'NACIONALIDAD', 'EMBARAZO', 'HABLA_LENGUA_INDIG', 'INDIGENA',
#        'DIABETES', 'EPOC', 'ASMA', 'INMUSUPR', 'HIPERTENSION', 'OTRA_COM',
#        'CARDIOVASCULAR', 'OBESIDAD', 'RENAL_CRONICA', 'TABAQUISMO',
#        'OTRO_CASO', 'TOMA_MUESTRA_LAB', 'RESULTADO_LAB',
#        'TOMA_MUESTRA_ANTIGENO', 'RESULTADO_ANTIGENO', 'CLASIFICACION_FINAL',
#        'MIGRANTE', 'PAIS_NACIONALIDAD', 'PAIS_ORIGEN', 'UCI'],
#       dtype='object')

# %%
F1 = COVID.iloc[90000:91000,:5].copy()
F1.head(5)
# Out:
#       FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM
# 90000          2022-08-09      41d7e2       1      12          26
# 90001          2022-08-09      257c69       1       4          17
# 90002          2022-08-09      2a9769       2      12           9
# 90003          2022-08-09      23bc87       1       4           5
# 90004          2022-08-09      2a5785       2      12           9

# %%
F2 = COVID.iloc[90000:91000,25:30].copy()
F2.head(2)
# Out:
#        OTRA_COM  CARDIOVASCULAR  OBESIDAD  RENAL_CRONICA  TABAQUISMO
# 90000         2               2         2              2           2
# 90001         2               2         1              2           2

# %%
UNION_F = pd.DataFrame ({
    "FECHA":F1["FECHA_ACTUALIZACION"],
    "REGISTRO":F1["ID_REGISTRO"],
    "SOBREPESO":F2["OBESIDAD"],
    "RENAL":F2["RENAL_CRONICA"]

})

UNION_F
# Out:
#             FECHA REGISTRO  SOBREPESO  RENAL
# 90000  2022-08-09   41d7e2          2      2
# 90001  2022-08-09   257c69          1      2
# 90002  2022-08-09   2a9769          1      2
# 90003  2022-08-09   23bc87          2      2
# 90004  2022-08-09   2a5785          2      2
# ...           ...      ...        ...    ...
# 90995  2022-08-09   35dd0b          2      2
# 90996  2022-08-09   3a6e7e          2      2
# 90997  2022-08-09   364623          2      2
# 90998  2022-08-09   3f63c1          2      2
# 90999  2022-08-09   376fc8          2      2
#
# [1000 rows x 4 columns]

# %%
DATA_ORDENADO = UNION_F.sort_values(["FECHA"], ascending = True).copy()
DATA_ORDENADO.head(3)
# Out:
#             FECHA REGISTRO  SOBREPESO  RENAL
# 90000  2022-08-09   41d7e2          2      2
# 90658  2022-08-09   2e2d29          2      2
# 90659  2022-08-09   3cc625          1      2

# %%
DATA_ORDENADO2 = UNION_F.sort_values(["SOBREPESO"], ascending = False).copy()
DATA_ORDENADO2
# Out:
#             FECHA REGISTRO  SOBREPESO  RENAL
# 90828  2022-08-09   26dec8         98     98
# 90000  2022-08-09   41d7e2          2      2
# 90677  2022-08-09   431f14          2      2
# 90648  2022-08-09   3a8cc1          2      2
# 90649  2022-08-09   443ee0          2      2
# ...           ...      ...        ...    ...
# 90200  2022-08-09   29633d          1      2
# 90563  2022-08-09   2d92bf          1      2
# 90904  2022-08-09   3e18b7          1      2
# 90659  2022-08-09   3cc625          1      2
# 90859  2022-08-09   45bb6b          1      2
#
# [1000 rows x 4 columns]

# %%
DATA_ORDENADO3 = UNION_F.sort_values(["RENAL"], ascending = True).copy()
DATA_ORDENADO3
# Out:
#             FECHA REGISTRO  SOBREPESO  RENAL
# 90981  2022-08-09   2749a0          2      1
# 90985  2022-08-09   2cd729          2      1
# 90706  2022-08-09   3a0bbe          2      1
# 90018  2022-08-09   249708          2      1
# 90043  2022-08-09   461631          1      1
# ...           ...      ...        ...    ...
# 90340  2022-08-09   2951ea          2      2
# 90341  2022-08-09   23cb6d          2      2
# 90342  2022-08-09   2d3a3c          2      2
# 90999  2022-08-09   376fc8          2      2
# 90828  2022-08-09   26dec8         98     98
#
# [1000 rows x 4 columns]

# %%
DATA_ORDENADO4 = UNION_F.sort_values(["REGISTRO","SOBREPESO"],ascending = True).copy()
DATA_ORDENADO4
# Out:
#             FECHA REGISTRO  SOBREPESO  RENAL
# 90032  2022-08-09   1e8652          1      2
# 90256  2022-08-09   1ec3aa          2      2
# 90948  2022-08-09   1ec97a          1      2
# 90979  2022-08-09   1ed47e          2      2
# 90688  2022-08-09   1edf97          2      2
# ...           ...      ...        ...    ...
# 90993  2022-08-09   46366c          2      2
# 90399  2022-08-09   46486a          2      2
# 90247  2022-08-09   464d1f          2      2
# 90747  2022-08-09   467c3d          2      2
# 90867  2022-08-09   467ead          2      2
#
# [1000 rows x 4 columns]

# %%
AUMENTAR_1 = lambda X : X + 1
NEGAR = lambda X : not(X)

# %%
COVID["COl_1"] = COVID["OBESIDAD"].transform(AUMENTAR_1).copy()
COVID
# Out:
#         FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM  SEXO  \
# 0                2022-08-09      z53cb3       2      12           9     2
# 1                2022-08-09      zze974       1       6          24     1
# 2                2022-08-09      zz7202       1      12          16     2
# 3                2022-08-09      z405fd       1      12           9     2
# 4                2022-08-09      z26b82       2      12           9     1
# ...                     ...         ...     ...     ...         ...   ...
# 8830340          2022-08-09     m0f93ef       2      12          15     1
# 8830341          2022-08-09     m08e5a6       2      12          15     1
# 8830342          2022-08-09     m0bea6e       2      12          15     1
# 8830343          2022-08-09     m00eab3       2      12          15     2
# 8830344          2022-08-09     m0bfb28       2      12          15     1
#
#          ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE  ...  \
# ...

# %%
TRANSFORMAR = COVID.iloc[100:50000,10:25].copy()
TRANSFORMAR
# Out:
#       FECHA_INGRESO FECHA_SINTOMAS   FECHA_DEF  INTUBADO  NEUMONIA  EDAD  \
# 100      2021-01-11     2021-01-07  9999-99-99        97         2     8
# 101      2021-12-24     2021-12-21  9999-99-99        97         2    32
# 102      2021-04-05     2021-04-05  9999-99-99        97         2    27
# 103      2021-09-01     2021-09-01  9999-99-99        97         2    48
# 104      2022-01-03     2021-12-31  9999-99-99        97         2    41
# ...             ...            ...         ...       ...       ...   ...
# 49995    2021-01-04     2021-01-04  9999-99-99        97         2    10
# 49996    2021-01-04     2021-01-04  9999-99-99        97         2    34
# 49997    2021-01-04     2021-01-03  9999-99-99        97         2    56
# 49998    2021-01-04     2021-01-03  9999-99-99        97         2    19
# 49999    2021-01-04     2021-01-04  9999-99-99        97         2    41
#
#        NACIONALIDAD  EMBARAZO  HABLA_LENGUA_INDIG  INDIGENA  DIABETES  EPOC  \
# ...

# %%
INCREMENTO_2 = lambda X : X + 2
NEGANDO_2 = lambda X : not(X)

# %%
TRANSFORMAR["COL_NUEVA"] = TRANSFORMAR["EMBARAZO"].transform(INCREMENTO_2).copy()
TRANSFORMAR
# Out:
#       FECHA_INGRESO FECHA_SINTOMAS   FECHA_DEF  INTUBADO  NEUMONIA  EDAD  \
# 100      2021-01-11     2021-01-07  9999-99-99        97         2     8
# 101      2021-12-24     2021-12-21  9999-99-99        97         2    32
# 102      2021-04-05     2021-04-05  9999-99-99        97         2    27
# 103      2021-09-01     2021-09-01  9999-99-99        97         2    48
# 104      2022-01-03     2021-12-31  9999-99-99        97         2    41
# ...             ...            ...         ...       ...       ...   ...
# 49995    2021-01-04     2021-01-04  9999-99-99        97         2    10
# 49996    2021-01-04     2021-01-04  9999-99-99        97         2    34
# 49997    2021-01-04     2021-01-03  9999-99-99        97         2    56
# 49998    2021-01-04     2021-01-03  9999-99-99        97         2    19
# 49999    2021-01-04     2021-01-04  9999-99-99        97         2    41
#
#        NACIONALIDAD  EMBARAZO  HABLA_LENGUA_INDIG  INDIGENA  DIABETES  EPOC  \
# ...

# %%
RESTAR_2 = lambda X : X - 2

# %%
TRANSFORMAR["MENOS_2"] = TRANSFORMAR["INTUBADO"].transform(RESTAR_2)
TRANSFORMAR
# Out:
#       FECHA_INGRESO FECHA_SINTOMAS   FECHA_DEF  INTUBADO  NEUMONIA  EDAD  \
# 100      2021-01-11     2021-01-07  9999-99-99        97         2     8
# 101      2021-12-24     2021-12-21  9999-99-99        97         2    32
# 102      2021-04-05     2021-04-05  9999-99-99        97         2    27
# 103      2021-09-01     2021-09-01  9999-99-99        97         2    48
# 104      2022-01-03     2021-12-31  9999-99-99        97         2    41
# ...             ...            ...         ...       ...       ...   ...
# 49995    2021-01-04     2021-01-04  9999-99-99        97         2    10
# 49996    2021-01-04     2021-01-04  9999-99-99        97         2    34
# 49997    2021-01-04     2021-01-03  9999-99-99        97         2    56
# 49998    2021-01-04     2021-01-03  9999-99-99        97         2    19
# 49999    2021-01-04     2021-01-04  9999-99-99        97         2    41
#
#        NACIONALIDAD  EMBARAZO  HABLA_LENGUA_INDIG  INDIGENA  DIABETES  EPOC  \
# ...

# %%
DIVIDIDO_3 = lambda X : X / 3

# %%
TRANSFORMAR["DIVIDIO_3"] = TRANSFORMAR["INTUBADO"].transform(DIVIDIDO_3).copy()
TRANSFORMAR
# Out:
#       FECHA_INGRESO FECHA_SINTOMAS   FECHA_DEF  INTUBADO  NEUMONIA  EDAD  \
# 100      2021-01-11     2021-01-07  9999-99-99        97         2     8
# 101      2021-12-24     2021-12-21  9999-99-99        97         2    32
# 102      2021-04-05     2021-04-05  9999-99-99        97         2    27
# 103      2021-09-01     2021-09-01  9999-99-99        97         2    48
# 104      2022-01-03     2021-12-31  9999-99-99        97         2    41
# ...             ...            ...         ...       ...       ...   ...
# 49995    2021-01-04     2021-01-04  9999-99-99        97         2    10
# 49996    2021-01-04     2021-01-04  9999-99-99        97         2    34
# 49997    2021-01-04     2021-01-03  9999-99-99        97         2    56
# 49998    2021-01-04     2021-01-03  9999-99-99        97         2    19
# 49999    2021-01-04     2021-01-04  9999-99-99        97         2    41
#
#        NACIONALIDAD  EMBARAZO  HABLA_LENGUA_INDIG  INDIGENA  DIABETES  EPOC  \
# ...

# %%
MULTIPLICADO_4 = lambda X : X * 4

# %%
TRANSFORMAR["MULTIPLICANDO_3"] = TRANSFORMAR["DIABETES"].transform(MULTIPLICADO_4).copy()
TRANSFORMAR
# Out:
#       FECHA_INGRESO FECHA_SINTOMAS   FECHA_DEF  INTUBADO  NEUMONIA  EDAD  \
# 100      2021-01-11     2021-01-07  9999-99-99        97         2     8
# 101      2021-12-24     2021-12-21  9999-99-99        97         2    32
# 102      2021-04-05     2021-04-05  9999-99-99        97         2    27
# 103      2021-09-01     2021-09-01  9999-99-99        97         2    48
# 104      2022-01-03     2021-12-31  9999-99-99        97         2    41
# ...             ...            ...         ...       ...       ...   ...
# 49995    2021-01-04     2021-01-04  9999-99-99        97         2    10
# 49996    2021-01-04     2021-01-04  9999-99-99        97         2    34
# 49997    2021-01-04     2021-01-03  9999-99-99        97         2    56
# 49998    2021-01-04     2021-01-03  9999-99-99        97         2    19
# 49999    2021-01-04     2021-01-04  9999-99-99        97         2    41
#
#        NACIONALIDAD  EMBARAZO  HABLA_LENGUA_INDIG  INDIGENA  DIABETES  EPOC  \
# ...

# %%
POTENCIA_2 = lambda X : X **2

# %%
TRANSFORMAR["AL_CUADRADO"] = TRANSFORMAR["INMUSUPR"].transform(POTENCIA_2).copy()
TRANSFORMAR
# Out:
#       FECHA_INGRESO FECHA_SINTOMAS   FECHA_DEF  INTUBADO  NEUMONIA  EDAD  \
# 100      2021-01-11     2021-01-07  9999-99-99        97         2     8
# 101      2021-12-24     2021-12-21  9999-99-99        97         2    32
# 102      2021-04-05     2021-04-05  9999-99-99        97         2    27
# 103      2021-09-01     2021-09-01  9999-99-99        97         2    48
# 104      2022-01-03     2021-12-31  9999-99-99        97         2    41
# ...             ...            ...         ...       ...       ...   ...
# 49995    2021-01-04     2021-01-04  9999-99-99        97         2    10
# 49996    2021-01-04     2021-01-04  9999-99-99        97         2    34
# 49997    2021-01-04     2021-01-03  9999-99-99        97         2    56
# 49998    2021-01-04     2021-01-03  9999-99-99        97         2    19
# 49999    2021-01-04     2021-01-04  9999-99-99        97         2    41
#
#        NACIONALIDAD  EMBARAZO  HABLA_LENGUA_INDIG  INDIGENA  DIABETES  EPOC  \
# ...

# %%
ELIMINAR_FILA = TRANSFORMAR.drop([100,101,102,103], axis = 0).copy()
ELIMINAR_FILA
# Out:
#       FECHA_INGRESO FECHA_SINTOMAS   FECHA_DEF  INTUBADO  NEUMONIA  EDAD  \
# 104      2022-01-03     2021-12-31  9999-99-99        97         2    41
# 105      2021-01-08     2021-01-08  9999-99-99        97         2    33
# 106      2021-01-26     2021-01-24  9999-99-99        97         2    57
# 107      2021-01-11     2021-01-04  9999-99-99        97         2    16
# 108      2021-10-18     2021-10-18  9999-99-99        97         2    23
# ...             ...            ...         ...       ...       ...   ...
# 49995    2021-01-04     2021-01-04  9999-99-99        97         2    10
# 49996    2021-01-04     2021-01-04  9999-99-99        97         2    34
# 49997    2021-01-04     2021-01-03  9999-99-99        97         2    56
# 49998    2021-01-04     2021-01-03  9999-99-99        97         2    19
# 49999    2021-01-04     2021-01-04  9999-99-99        97         2    41
#
#        NACIONALIDAD  EMBARAZO  HABLA_LENGUA_INDIG  INDIGENA  DIABETES  EPOC  \
# ...

# %%
ELIMINAR_FILA = TRANSFORMAR.drop([110,120,130,140], axis = 0).copy().reset_index()
ELIMINAR_FILA.head(30)
# Out:
#     index FECHA_INGRESO FECHA_SINTOMAS   FECHA_DEF  INTUBADO  NEUMONIA  EDAD  \
# 0     100    2021-01-11     2021-01-07  9999-99-99        97         2     8
# 1     101    2021-12-24     2021-12-21  9999-99-99        97         2    32
# 2     102    2021-04-05     2021-04-05  9999-99-99        97         2    27
# 3     103    2021-09-01     2021-09-01  9999-99-99        97         2    48
# 4     104    2022-01-03     2021-12-31  9999-99-99        97         2    41
# 5     105    2021-01-08     2021-01-08  9999-99-99        97         2    33
# 6     106    2021-01-26     2021-01-24  9999-99-99        97         2    57
# 7     107    2021-01-11     2021-01-04  9999-99-99        97         2    16
# 8     108    2021-10-18     2021-10-18  9999-99-99        97         2    23
# 9     109    2021-02-05     2021-02-05  9999-99-99        97         2    33
# 10    111    2021-01-26     2021-01-24  9999-99-99        97         2    15
# ...

# %%
ELIMINAR_FILA = TRANSFORMAR.drop(range(100,150), axis = 0).copy()
ELIMINAR_FILA
# Out:
#       FECHA_INGRESO FECHA_SINTOMAS   FECHA_DEF  INTUBADO  NEUMONIA  EDAD  \
# 150      2021-01-27     2021-01-25  9999-99-99        97         2    17
# 151      2021-12-24     2021-12-19  9999-99-99        97         2    47
# 152      2021-01-09     2021-01-09  9999-99-99        97         2    26
# 153      2021-04-05     2021-04-05  9999-99-99        97         2    61
# 154      2021-10-18     2021-10-16  9999-99-99        97         2    31
# ...             ...            ...         ...       ...       ...   ...
# 49995    2021-01-04     2021-01-04  9999-99-99        97         2    10
# 49996    2021-01-04     2021-01-04  9999-99-99        97         2    34
# 49997    2021-01-04     2021-01-03  9999-99-99        97         2    56
# 49998    2021-01-04     2021-01-03  9999-99-99        97         2    19
# 49999    2021-01-04     2021-01-04  9999-99-99        97         2    41
#
#        NACIONALIDAD  EMBARAZO  HABLA_LENGUA_INDIG  INDIGENA  DIABETES  EPOC  \
# ...

# %%
ELIMINAR_FILA.head(5)
# Out:
#    index FECHA_INGRESO FECHA_SINTOMAS   FECHA_DEF  INTUBADO  NEUMONIA  EDAD  \
# 0    100    2021-01-11     2021-01-07  9999-99-99        97         2     8
# 1    101    2021-12-24     2021-12-21  9999-99-99        97         2    32
# 2    102    2021-04-05     2021-04-05  9999-99-99        97         2    27
# 3    103    2021-09-01     2021-09-01  9999-99-99        97         2    48
# 4    104    2022-01-03     2021-12-31  9999-99-99        97         2    41
#
#    NACIONALIDAD  EMBARAZO  HABLA_LENGUA_INDIG  ...  DIABETES  EPOC  ASMA  \
# 0             1         2                   2  ...         2     2     2
# 1             1         2                   2  ...         2     2     2
# 2             1         2                   2  ...         2     2     2
# 3             1         2                   2  ...         2     2     2
# 4             1        97                   2  ...         2     2     2
#
# ...

# %%
FILA_NUEVA = ELIMINAR_FILA.drop(["INTUBADO"], axis = 1).copy()
FILA_NUEVA
# Out:
#        index FECHA_INGRESO FECHA_SINTOMAS   FECHA_DEF  NEUMONIA  EDAD  \
# 0        100    2021-01-11     2021-01-07  9999-99-99         2     8
# 1        101    2021-12-24     2021-12-21  9999-99-99         2    32
# 2        102    2021-04-05     2021-04-05  9999-99-99         2    27
# 3        103    2021-09-01     2021-09-01  9999-99-99         2    48
# 4        104    2022-01-03     2021-12-31  9999-99-99         2    41
# ...      ...           ...            ...         ...       ...   ...
# 49891  49995    2021-01-04     2021-01-04  9999-99-99         2    10
# 49892  49996    2021-01-04     2021-01-04  9999-99-99         2    34
# 49893  49997    2021-01-04     2021-01-03  9999-99-99         2    56
# 49894  49998    2021-01-04     2021-01-03  9999-99-99         2    19
# 49895  49999    2021-01-04     2021-01-04  9999-99-99         2    41
#
#        NACIONALIDAD  EMBARAZO  HABLA_LENGUA_INDIG  INDIGENA  DIABETES  EPOC  \
# ...

# %%
FILA_NUEVA = ELIMINAR_FILA.drop(["index"], axis = 1).copy()
FILA_NUEVA
# Out:
#       FECHA_INGRESO FECHA_SINTOMAS   FECHA_DEF  INTUBADO  NEUMONIA  EDAD  \
# 0        2021-01-11     2021-01-07  9999-99-99        97         2     8
# 1        2021-12-24     2021-12-21  9999-99-99        97         2    32
# 2        2021-04-05     2021-04-05  9999-99-99        97         2    27
# 3        2021-09-01     2021-09-01  9999-99-99        97         2    48
# 4        2022-01-03     2021-12-31  9999-99-99        97         2    41
# ...             ...            ...         ...       ...       ...   ...
# 49891    2021-01-04     2021-01-04  9999-99-99        97         2    10
# 49892    2021-01-04     2021-01-04  9999-99-99        97         2    34
# 49893    2021-01-04     2021-01-03  9999-99-99        97         2    56
# 49894    2021-01-04     2021-01-03  9999-99-99        97         2    19
# 49895    2021-01-04     2021-01-04  9999-99-99        97         2    41
#
#        NACIONALIDAD  EMBARAZO  HABLA_LENGUA_INDIG  INDIGENA  DIABETES  EPOC  \
# ...

# %%
FILA_NUEVA = ELIMINAR_FILA.drop(["COL_NUEVA","MENOS_2","DIVIDIO_3","MULTIPLICANDO_3"], axis = 1)
FILA_NUEVA
# Out:
#        index FECHA_INGRESO FECHA_SINTOMAS   FECHA_DEF  INTUBADO  NEUMONIA  \
# 0        100    2021-01-11     2021-01-07  9999-99-99        97         2
# 1        101    2021-12-24     2021-12-21  9999-99-99        97         2
# 2        102    2021-04-05     2021-04-05  9999-99-99        97         2
# 3        103    2021-09-01     2021-09-01  9999-99-99        97         2
# 4        104    2022-01-03     2021-12-31  9999-99-99        97         2
# ...      ...           ...            ...         ...       ...       ...
# 49891  49995    2021-01-04     2021-01-04  9999-99-99        97         2
# 49892  49996    2021-01-04     2021-01-04  9999-99-99        97         2
# 49893  49997    2021-01-04     2021-01-03  9999-99-99        97         2
# 49894  49998    2021-01-04     2021-01-03  9999-99-99        97         2
# 49895  49999    2021-01-04     2021-01-04  9999-99-99        97         2
#
#        EDAD  NACIONALIDAD  EMBARAZO  HABLA_LENGUA_INDIG  INDIGENA  DIABETES  \
# ...

# %%
ELIMINAR_COLUMNA = ELIMINAR_FILA.drop(["AL_CUADRADO"], axis = 1).copy()
ELIMINAR_COLUMNA
# Out:
#        index FECHA_INGRESO FECHA_SINTOMAS   FECHA_DEF  INTUBADO  NEUMONIA  \
# 0        100    2021-01-11     2021-01-07  9999-99-99        97         2
# 1        101    2021-12-24     2021-12-21  9999-99-99        97         2
# 2        102    2021-04-05     2021-04-05  9999-99-99        97         2
# 3        103    2021-09-01     2021-09-01  9999-99-99        97         2
# 4        104    2022-01-03     2021-12-31  9999-99-99        97         2
# ...      ...           ...            ...         ...       ...       ...
# 49891  49995    2021-01-04     2021-01-04  9999-99-99        97         2
# 49892  49996    2021-01-04     2021-01-04  9999-99-99        97         2
# 49893  49997    2021-01-04     2021-01-03  9999-99-99        97         2
# 49894  49998    2021-01-04     2021-01-03  9999-99-99        97         2
# 49895  49999    2021-01-04     2021-01-04  9999-99-99        97         2
#
#        EDAD  NACIONALIDAD  EMBARAZO  HABLA_LENGUA_INDIG  INDIGENA  DIABETES  \
# ...

# %%
QUITAR_FIL = ELIMINAR_FILA.drop(range(0,50), axis = 0).copy().reset_index()
QUITAR_FIL
# Out:
#        level_0  index FECHA_INGRESO FECHA_SINTOMAS   FECHA_DEF  INTUBADO  \
# 0           50    154    2021-10-18     2021-10-16  9999-99-99        97
# 1           51    155    2021-12-24     2021-12-24  9999-99-99        97
# 2           52    156    2021-02-06     2021-02-06  9999-99-99        97
# 3           53    157    2021-01-27     2021-01-25  9999-99-99        97
# 4           54    158    2021-12-02     2021-12-02  9999-99-99        97
# ...        ...    ...           ...            ...         ...       ...
# 49841    49891  49995    2021-01-04     2021-01-04  9999-99-99        97
# 49842    49892  49996    2021-01-04     2021-01-04  9999-99-99        97
# 49843    49893  49997    2021-01-04     2021-01-03  9999-99-99        97
# 49844    49894  49998    2021-01-04     2021-01-03  9999-99-99        97
# 49845    49895  49999    2021-01-04     2021-01-04  9999-99-99        97
#
#        NEUMONIA  EDAD  NACIONALIDAD  EMBARAZO  ...  DIABETES  EPOC  ASMA  \
# ...

# %%
BORRAR_INDEX = ELIMINAR_FILA.drop(["index"], axis = 1 ).copy()
BORRAR_INDEX
# Out:
#       FECHA_INGRESO FECHA_SINTOMAS   FECHA_DEF  INTUBADO  NEUMONIA  EDAD  \
# 0        2021-01-11     2021-01-07  9999-99-99        97         2     8
# 1        2021-12-24     2021-12-21  9999-99-99        97         2    32
# 2        2021-04-05     2021-04-05  9999-99-99        97         2    27
# 3        2021-09-01     2021-09-01  9999-99-99        97         2    48
# 4        2022-01-03     2021-12-31  9999-99-99        97         2    41
# ...             ...            ...         ...       ...       ...   ...
# 49891    2021-01-04     2021-01-04  9999-99-99        97         2    10
# 49892    2021-01-04     2021-01-04  9999-99-99        97         2    34
# 49893    2021-01-04     2021-01-03  9999-99-99        97         2    56
# 49894    2021-01-04     2021-01-03  9999-99-99        97         2    19
# 49895    2021-01-04     2021-01-04  9999-99-99        97         2    41
#
#        NACIONALIDAD  EMBARAZO  HABLA_LENGUA_INDIG  INDIGENA  DIABETES  EPOC  \
# ...

# %%
BORRAR_FE = ELIMINAR_FILA.drop(["FECHA_INGRESO"], axis = 1).copy()
BORRAR_FE
# Out:
#        index FECHA_SINTOMAS   FECHA_DEF  INTUBADO  NEUMONIA  EDAD  \
# 0        100     2021-01-07  9999-99-99        97         2     8
# 1        101     2021-12-21  9999-99-99        97         2    32
# 2        102     2021-04-05  9999-99-99        97         2    27
# 3        103     2021-09-01  9999-99-99        97         2    48
# 4        104     2021-12-31  9999-99-99        97         2    41
# ...      ...            ...         ...       ...       ...   ...
# 49891  49995     2021-01-04  9999-99-99        97         2    10
# 49892  49996     2021-01-04  9999-99-99        97         2    34
# 49893  49997     2021-01-03  9999-99-99        97         2    56
# 49894  49998     2021-01-03  9999-99-99        97         2    19
# 49895  49999     2021-01-04  9999-99-99        97         2    41
#
#        NACIONALIDAD  EMBARAZO  HABLA_LENGUA_INDIG  INDIGENA  DIABETES  EPOC  \
# 0                 1         2                   2         2         2     2
# ...

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '1.3.4'

# %%
pd.show_version?
# Out:
# Object `pd.show_version` not found.

# %%
print(pd.__version__)
# Out:
# 1.3.4

# %%
pd.read_csv?

# %%
import pandas_datareader as pdr
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11004/288088074.py in <module>
# ----> 1 import pandas_datareader as pdr
#
# ModuleNotFoundError: No module named 'pandas_datareader'

# %%
pip install pandas-datareader
# Out:
# ...
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# ...

# %%
import pandas as pd
import pandas_datareader as pdr
